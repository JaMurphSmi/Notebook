# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import plotly.plotly as py
import plotly.graph_objs as go
from plotly import tools
from plotly.offline import iplot, init_notebook_mode
# %matplotlib inline

# %%
data = pd.read_csv('C:/Users/jakem/Desktop/Data_Sets/survey_results_public.csv')

# %%
data.head(4)
# Out:
#    Respondent                                       Professional ProgramHobby  \
# 0           1                                            Student    Yes, both
# 1           2                                            Student    Yes, both
# 2           3                             Professional developer    Yes, both
# 3           4  Professional non-developer who sometimes write...    Yes, both
#
#           Country      University                        EmploymentStatus  \
# 0   United States              No  Not employed, and not looking for work
# 1  United Kingdom  Yes, full-time                      Employed part-time
# 2  United Kingdom              No                      Employed full-time
# 3   United States              No                      Employed full-time
#
#                                      FormalEducation  \
# 0                                   Secondary school
# 1  Some college/university study without earning ...
# ...

# %%
data['Country'].value_counts()[0:15].plot(kind='bar',figsize=(12,10))

# %%
data['EmploymentStatus'].value_counts()[0:10].plot(kind='bar',figsize=(12,10))

# %%
data['CompanySize'].value_counts()[0:10].plot(kind='bar',figsize=(12,10))

# %%
data['WorkStart'].value_counts()[0:10].plot(kind='bar',figsize=(12,10))

# %%
data['Race'].value_counts()[0:10].plot(kind='bar',figsize=(12,10))

# %%
data[data['Country'] == 'United States']['EducationImportant'].value_counts().plot(kind='pie',figsize=(12,10))

# %%
data[data['Country'] == 'United States']['JobSatisfaction'].value_counts().plot(kind='pie',figsize=(12,10))

# %%
data[data['Country'] == 'United States']['JobSatisfaction'].value_counts().plot(kind='bar',title="Barchart of Happiness",figsize=(12,10))

# %%
data[data['Country'] == 'United States']['Professional'].value_counts().plot(kind='bar',title="Barchart of Happiness",figsize=(12,10))

# %%
newData = data['Race']

# %%
from collections import Counter
Counter(newData)
# Out:
# Counter({'White or of European descent': 23415,
#          nan: 18359,
#          'Hispanic or Latino/Latina': 1289,
#          'Native American, Pacific Islander, or Indigenous Australian; White or of European descent': 110,
#          'I prefer not to say': 810,
#          'South Asian': 2657,
#          'Middle Eastern': 899,
#          'Hispanic or Latino/Latina; White or of European descent': 429,
#          'I don’t know': 518,
#          'Hispanic or Latino/Latina; Native American, Pacific Islander, or Indigenous Australian': 7,
#          'Middle Eastern; White or of European descent': 196,
#          'East Asian': 1285,
#          'Black or of African descent; White or of European descent': 59,
#          'Black or of African descent; East Asian; White or of European descent': 2,
#          'Middle Eastern; I don’t know': 6,
#          'East Asian; White or of European descent': 134,
#          'East Asian; South Asian; I don’t know': 3,
# ...
